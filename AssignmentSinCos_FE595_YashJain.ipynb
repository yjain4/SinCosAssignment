# %%
#Assignment1 FE 595 
import numpy as npy
import matplotlib.pyplot as mplt

# %%
def plot(i,j,k):
    a = npy.arange(i,j*npy.pi,k)
    b = npy.sin(a)
    c = npy.cos(a)
    figu = mplt.figure()
    axi = figu.add_subplot(1, 1, 1)
    mplt.plot(a,b, 'b', label='sin(x)')
    mplt.plot(a,c, 'c', label='cos(x)')

    mplt.plot(a,b)
    mplt.plot(a,c)
    mplt.legend(loc='best')

# %%
result=plot(0,0.4,0.1)
print(result)
# Out:
# None
